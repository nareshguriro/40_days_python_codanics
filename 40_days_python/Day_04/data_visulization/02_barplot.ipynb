# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
phool = sns.load_dataset("Iris")
#draw a line plot
sns.barplot(x='species', y='sepal_width',data=phool)
plt.title('flowers plot')
#sns.set_style("dark")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
kashti = sns.load_dataset("Titanic")
#draw a line plot
kashti

#plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
kashti = sns.load_dataset("titanic")
sns.barplot(x='sex', y='alone',hue='who',data=kashti)
plt.title('titanic kashti')
# Out:
# Text(0.5, 1.0, 'titanic kashti')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
kashti = sns.load_dataset("titanic")
sns.barplot(x='sex', y='alone',hue='who',data=kashti,order=['female','male'])
plt.title('titanic kashti')
# Out:
# Text(0.5, 1.0, 'titanic kashti')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
kashti = sns.load_dataset("titanic")
sns.barplot(x='sex', y='alone',hue='who',data=kashti,order=['female','male'],color='yellow')
plt.title('titanic kashti')
# Out:
# Text(0.5, 1.0, 'titanic kashti')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
kashti = sns.load_dataset("titanic")
sns.barplot(x='sex', y='alone',hue='who',data=kashti,order=['female','male'],color='yellow',ci=None)
plt.title('titanic kashti')
# Out:
# C:\Users\B S COM\AppData\Local\Temp\ipykernel_8648\4075537801.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='sex', y='alone',hue='who',data=kashti,order=['female','male'],color='yellow',ci=None)
# Text(0.5, 1.0, 'titanic kashti')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
kashti = sns.load_dataset("titanic")
sns.barplot(x='sex', y='alone',hue='who',data=kashti,order=['female','male'],color='yellow', ci=None,
            palette='pastel')
plt.title('titanic kashti')
# Out:
# C:\Users\B S COM\AppData\Local\Temp\ipykernel_8648\113514689.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='sex', y='alone',hue='who',data=kashti,order=['female','male'],color='yellow', ci=None,
# Text(0.5, 1.0, 'titanic kashti')

# %%
import seaborn as sns
import numpy 
import matplotlib.pyplot as plt
#load dataset
kashti = sns.load_dataset("titanic")
sns.barplot(x ="class",y="fare",hue="sex",data=kashti,estimator=median, saturation =1)
plt.title('titanic kashti')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load dataset
phool = sns.load_dataset("Iris")
#draw a line plot
sns.barplot(x='species', y='sepal_width',data=phool)
plt.title('flowers plot')
sns.set_style("dark")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean
#load dataset
kashti = sns.load_dataset("titanic")
#draw a line plot
sns.barplot(x="fare",y="class",hue="sex",data=kashti,estimator=mean,saturation=1,linewidth=3,facecolor=(1,1,1,0),errcolor="0",edgecolor="2")
