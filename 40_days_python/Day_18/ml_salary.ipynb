# %% [markdown]
# Linear Regression Model for Salary Experience vs salary dataset

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#importing dataset
df=pd.read_csv('salary_data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#wrangled the data
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df

# %%
sns.boxplot(data=df, x=('Salary'))
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.lmplot(data=df, x='YearsExperience', y='Salary')

# %%
X= df[['YearsExperience']]
y=df['Salary']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
#call the model 
model =LinearRegression()
#train the model
model.fit(X,y)
#predict
model.predict([[2.2]])
# Out:
# c:\Users\B S COM\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([46582.11730587])

# %% [markdown]
# ### Model Evolution
# #r2
# #mean square error
# #MAE
# #RMSE

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8)

# %%
#Model
model=LinearRegression()
model.fit(X_train,y_train)
#prediction
predictions= model.predict(X_test)
predictions
# Out:
# array([ 61943.72279066,  55027.30058685, 112334.79884702,  36254.15460507,
#        118263.160736  ,  52063.11964235])

# %%
#compare 
#Now to know the accuracy of the model compare prediction values which are based on  X_test to actual y_test values

sns.scatterplot(x=y_test, y= predictions)
# Out:
# <Axes: xlabel='Salary'>

# %% [markdown]
# it looks good

# %%
model.score(X_test,y_test)
# Out:
# 0.950905224635566

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
MAE= mean_absolute_error(y_true=y_test,y_pred=predictions)
MSE=mean_squared_error(y_true=y_test,y_pred=predictions)
RMSE=mean_squared_error(y_true=y_test,y_pred=predictions ,squared=False)
r2=r2_score(y_true=y_test,y_pred=predictions)
print('MAE :',MAE)
print('MSE :',MSE)
print('RMSE :',RMSE)
print('r2 :',r2)
# Out:
# MAE : 4794.543855297711
# MSE : 33204135.22029541
# RMSE : 5762.302944161771
# r2 : 0.950905224635566
